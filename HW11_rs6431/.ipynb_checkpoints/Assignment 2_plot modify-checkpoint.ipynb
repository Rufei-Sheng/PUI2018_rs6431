# %%
import pandas as pd
import os
import urllib
from zipfile import ZipFile 
import geopandas
import matplotlib.pyplot as plt
import shapely
from fiona.crs import from_epsg
# %matplotlib inline

# %% [markdown]
# # Modified version of Graph

# %% [markdown]
# ### 1. Got the Manhattan area which contains Time-Square

# %%
#another way to get Manhattan map data with detailed information:
#!curl https://www1.nyc.gov/assets/planning/download/zip/data-maps/open-data/mn_mappluto_18v1.zip > man_detail.zip

# %%
#!mv man_detail.zip $PUIDATA

# %%
#zipgz = ZipFile(os.getenv('PUIDATA') + '/' + 'man_detail.zip')
#zipgz.extractall(os.getenv('PUIDATA'))
MAN = geopandas.GeoDataFrame.from_file(os.getenv('PUIDATA') + '/MNMapPLUTO.shp')
MAN.head()
# Out:
#   Borough  Block   Lot   CD CT2010 CB2010 SchoolDist  Council  ZipCode  \
# 0      MN   1545    52  108    138   4000         02        5    10028
# 1      MN    723  7501  104     93   6000         02        3    10001
# 2      MN   1680    48  111    170   5000         04        8    10029
# 3      MN   1385    32  108    130   2003         02        4    10021
# 4      MN   1197    27  107    169   5000         03        6    10024
#
#   FireComp                        ...                                APPBBL  \
# 0     E022                        ...                          0.000000e+00
# 1     E003                        ...                          1.007230e+09
# 2     E091                        ...                          0.000000e+00
# 3     E039                        ...                          0.000000e+00
# 4     E074                        ...                          0.000000e+00
#
#       APPDate  PLUTOMapID FIRM07_FLA PFIRM15_FL Version MAPPLUTO_F  \
# 0        None           1       None       None    18V1          0
# 1  11/30/2006           1       None       None    18V1          7
# 2        None           1          1          1    18V1          0
# 3        None           1       None       None    18V1          0
# 4        None           1       None       None    18V1          0
#
#      SHAPE_area   SHAPE_len                                           geometry
# 0   2867.154705  260.428942  POLYGON ((997277.2344360352 221816.0936279297,...
# 1  10907.639931  417.764545  POLYGON ((984164.5626220703 211846.0704345703,...
# 2   2665.033424  256.893308  POLYGON ((1000742.195800781 227910.6640014648,...
# 3  15302.920914  505.033271  POLYGON ((994007.6885986328 219880.4284057617,...
# 4   4374.612456  295.652483  POLYGON ((992273.6849975586 224863.4904174805,...
#
# [5 rows x 91 columns]

# %%
MAN.plot(edgecolor='black', color='white', figsize=(8, 8))

# %%
time_square = MAN[MAN['ZipCode'] == 10036]
time_square.plot(color='white', edgecolor='black', figsize=(10, 10))
plt.title('Time-Square area', fontsize=20)
# Out:
# Text(0.5,1,'Time-Square area')

# %% [markdown]
# **Figure 1:** The geo graph of time square selected from Manhanttan map. It shows detailed road information.

# %% [markdown]
# ### 2. Get the food & beverage data:

# %%
#!curl https://data.cityofnewyork.us/api/views/kh2m-kcyz/rows.csv?accessType=DOWNLOAD > Food.csv
#!mv Food.csv $PUIDATA

# %%
FOOD = pd.read_csv(os.getenv('PUIDATA') + '/Food.csv')
FOOD.head()
# Out:
#                    Company Name  Subindustry Sub Subindustry  \
# 0                   Europa Cafe  Café / Deli             NaN
# 1                       Ranch 1  Quick Serve       Fast Food
# 2                  Sosa Borella   Full Serve     Argentinian
# 3  Mi Nidito (Cantina Mexicana)   Full Serve         Mexican
# 4                     Starbucks       Coffee             NaN
#
#                           Address           Phone  \
# 0                      3 Times Sq    212-239-0160
# 1                  832 Eighth Ave      2129561111
# 2                  832 Eighth Ave  (212) 262-8282
# 3                  852 Eighth Ave  (212) 265-0022
# 4  871-879 Eighth Ave, Suite# 871      2122467699
#
#                        Website  Borough  Postcode   Latitude  Longitude  \
# 0           www.euorpacafe.com        1   10036.0  40.756376 -73.986713
# 1                          NaN        1   10019.0  40.762444 -73.985983
# 2  http://www.sosaborella.com/        1   10019.0  40.762444 -73.985983
# 3                          NaN        1   10019.0  40.763128 -73.985481
# 4            www.starbucks.com        1   10019.0  40.763644 -73.985134
#
#    Community Board  Community Council   Census Tract        BIN           BBL  \
# 0              5.0                 3.0         119.0  1024686.0  1.010140e+09
# 1              5.0                 3.0         131.0  1024809.0  1.010220e+09
# 2              5.0                 3.0         131.0  1024809.0  1.010220e+09
# 3              5.0                 3.0         131.0  1081646.0  1.010230e+09
# 4              4.0                 3.0         133.0  1025257.0  1.010438e+09
#
#                                                  NTA  \
# 0  Midtown-Midtown South                         ...
# 1  Midtown-Midtown South                         ...
# 2  Midtown-Midtown South                         ...
# 3  Midtown-Midtown South                         ...
# 4  Clinton                                       ...
#
#                                           Location 1
# 0                3 Times Sq\n(40.756376, -73.986713)
# 1            832 Eighth Ave\n(40.762444, -73.985983)
# 2            832 Eighth Ave\n(40.762444, -73.985983)
# 3            852 Eighth Ave\n(40.763128, -73.985481)
# 4  871-879 Eighth Ave, Suite# 871\n(40.763644, -7...

# %%
FOOD_1 = FOOD[FOOD['Postcode'] == 10036]

# %%
FOOD_1.dropna(inplace=True)
FOOD_1['Location'] = list(zip(FOOD_1.Longitude, FOOD_1.Latitude))
FOOD_1 = FOOD_1[(True - FOOD_1['Location'].isin([0]))]
FOOD_1['geometry'] = FOOD_1[['Location']].applymap(lambda x: shapely.geometry.Point(x))
FOOD_1 = geopandas.GeoDataFrame(FOOD_1)
FOOD_1.head()
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/pandas/computation/expressions.py:181: UserWarning: evaluating in Python space because the '-' operator is not supported by numexpr for the bool dtype, use '^' instead
#   unsupported[op_str]))
#                          Company Name  Subindustry Sub Subindustry  \
# 21      The Library @ Paramount Hotel   Full Serve        American
# 24                      Auntie Anne's  Quick Serve       Fast Food
# 25       B.B. King Blues Club & Grill   Full Serve        American
# 26  Cold Stone Creamery/ Tim Horton's  Quick Serve         Dessert
# 32                 Shula's Steakhouse   Full Serve      Steakhouse
#
#            Address         Phone                            Website  Borough  \
# 21   235 W 46th St  212 827-4183  www.paramountNewYork.solmelia.com        1
# 24  664 Eighth Ave    2127641542                www.auntieannes.com        1
# 25   237 W 42nd St    2129974144                www.bbkingblues.com        1
# 26   243 W 42nd St    2123981882          www.coldstonecreamery.com        1
# 32   250 W 43rd St    2122012776            http://www.donshula.com        1
#
#     Postcode   Latitude  Longitude  Community Board  Community Council   \
# 21   10036.0  40.759132 -73.986348              5.0                 3.0
# 24   10036.0  40.757436 -73.989633              5.0                 3.0
# 25   10036.0  40.756785 -73.988702              5.0                 3.0
# 26   10036.0  40.756821 -73.988789              5.0                 3.0
# 32   10036.0  40.757309 -73.987901              5.0                 3.0
#
#     Census Tract        BIN           BBL  \
# 21         125.0  1024737.0  1.010180e+09
# 24         119.0  1087142.0  1.010140e+09
# 25         119.0  1087142.0  1.010140e+09
# 26         119.0  1087142.0  1.010140e+09
# 32         119.0  1085096.0  1.010140e+09
#
#                                                   NTA  \
# 21  Midtown-Midtown South                         ...
# 24  Midtown-Midtown South                         ...
# 25  Midtown-Midtown South                         ...
# 26  Midtown-Midtown South                         ...
# 32  Midtown-Midtown South                         ...
#
#                                  Location 1                 Location  \
# 21   235 W 46th St\n(40.759132, -73.986348)  (-73.986348, 40.759132)
# 24  664 Eighth Ave\n(40.757436, -73.989633)  (-73.989633, 40.757436)
# 25   237 W 42nd St\n(40.756785, -73.988702)  (-73.988702, 40.756785)
# 26   243 W 42nd St\n(40.756821, -73.988789)  (-73.988789, 40.756821)
# 32   250 W 43rd St\n(40.757309, -73.987901)  (-73.987901, 40.757309)
#
#                                 geometry
# 21  POINT (-73.98634799999999 40.759132)
# 24          POINT (-73.989633 40.757436)
# 25          POINT (-73.988702 40.756785)
# 26          POINT (-73.988789 40.756821)
# 32  POINT (-73.98790100000001 40.757309)

# %%
type(FOOD_1)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
FOOD_1.crs = from_epsg(4326)
FOOD_1 = FOOD_1.to_crs({'init': 'epsg:2263'})
FOOD_1.crs
# Out:
# {'init': 'epsg:2263'}

# %%
#crs = {'init':'epsg:2263'}
#FOOD_1 = geopandas.GeoDataFrame(FOOD_1, crs=crs, geometry=FOOD_1['geometry'])

# %%
#method 2:
crs = {'init':'epsg:2263'}
FOOD_1 = geopandas.GeoDataFrame(FOOD_1, crs=crs, geometry=FOOD_1['geometry'])
time_square = geopandas.GeoDataFrame(time_square, crs=crs, geometry=time_square['geometry'])

# %%
#FOOD_1.crs = from_epsg(4326)
#FOOD_1 = FOOD_1.to_crs({'init': 'epsg:2263'})
#FOOD_1.crs

# %%
time_square = time_square.to_crs({'init': 'epsg:2263'})

# %%
FOOD_1.crs
# Out:
# {'init': 'epsg:2263'}

# %%
time_square.crs
# Out:
# {'init': 'epsg:2263'}

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
time_square.to_crs(epsg=2263).plot(color='white', edgecolor='black', ax=ax1)
FOOD_1.to_crs(epsg=2263).plot(column='Sub Subindustry', marker='o', markersize=35, legend=True, ax=ax1)
ax1.set_title('Times Square Food & Beverage Locations by Food Type',  fontsize=20)
ax1.axis('off')

time_square.to_crs(epsg=2263).plot(color='white', edgecolor='black', ax=ax2)
FOOD_1.to_crs(epsg=2263).plot(column='Subindustry', marker='o', markersize=35, legend=True, ax=ax2)
ax2.set_title('Times Square Food & Beverage Locations by Service Type',  fontsize=20)
ax2.axis('off')
# Out:
# (982622.13135681313,
#  990621.19231262221,
#  213701.14834888949,
#  219026.17886036061)

# %% [markdown]
# **Figure 2** Times Square Food & Beverage Locations by Food Type and by service type. The food type is really diversied, and seems have no clustering pattern. My initial thought that the same cuisine tend to gather together cannot be proved by this data. For the service type, more restaurants have full serve and tend to clustering in the close space.

# %% [markdown]
# # Original graph

# %%
#another way to get Manhattan map data
#with detailed information:
#https://www1.nyc.gov/assets/planning/download/zip/data-maps/open-data/mn_mappluto_18v1.zip

#From NYU website:
#!curl -k https://archive.nyu.edu/retrieve/74708/nyu_2451_34509.zip > NYCzip.zip
#Filter Manhattan out of NYC:
#Man = NYC[(NYC.zipcode >10000)&(NYC.zipcode <10300)&(NYC.zipcode!=10026)&(NYC.zipcode!=10027)&(NYC.zipcode!=10029)&(NYC.zipcode!=10030)(NYC.zipcode!=10037)&(NYC.zipcode!=10038)]

# %%
#Got data from Public Use Microdata Area(PUMA)
urllib.request.urlretrieve('https://data.cityofnewyork.us/api/geospatial/cwiz-gcty?method=export&format=Shapefile', "file.gz")
# !mv file.gz $PUIDATA
zipgz = ZipFile(os.getenv('PUIDATA') + '/' + 'file.gz')
zipgz.extractall(os.getenv('PUIDATA'))


NYC = geopandas.GeoDataFrame.from_file(os.getenv('PUIDATA') + '/' + 'geo_export_947ddeb1-5148-4a2a-8619-c999a49409be.shp')
NYC.head()

# %%
NYC['puma'] = NYC['puma'].astype(int)
NYC = NYC[(NYC['puma'] == 3807)]
NYC.plot(edgecolor='black', figsize=(8, 8))
plt.title('Manhattan Time-Square area', fontsize=20)

# %% [markdown]
# Figure 1: The contour of Manhattan area which contains Time-Square

# %%
NYC.crs

# %% [markdown]
# ### 2. Got the Food data in Time-square

# %%
# !curl https://data.cityofnewyork.us/api/views/kh2m-kcyz/rows.csv?accessType=DOWNLOAD > Food.csv

# %%
# !mv Food.csv $PUIDATA

# %%
FOOD = pd.read_csv(os.getenv('PUIDATA') + '/Food.csv')
FOOD.head()

# %%
FOOD_1 = FOOD[['Subindustry', 'Borough', 'Postcode', 'Latitude', 'Longitude']]
FOOD_1 = geopandas.GeoDataFrame(FOOD_1)
FOOD_1.dropna(inplace=True)
FOOD_1.head()

# %%
FOOD_1 = FOOD_1[(FOOD_1['Postcode'] >10000)&
                  (FOOD_1['Postcode'] <10300)&
                  (FOOD_1['Postcode']!=10026)&
                  (FOOD_1['Postcode']!=10027)&
                  (FOOD_1['Postcode']!=10029)&
                  (FOOD_1['Postcode']!=10030)&
                  (FOOD_1['Postcode']!=10037)&
                  (FOOD_1['Postcode']!=10038)]

# %%
FOOD_1['Location'] = list(zip(FOOD_1.Longitude, FOOD_1.Latitude))
FOOD_1 = FOOD_1[(True - FOOD_1['Location'].isin([0]))]
FOOD_1['geometry'] = FOOD_1[['Location']].applymap(lambda x: shapely.geometry.Point(x))
FOOD_1.head()

# %%
FOOD_1 = geopandas.GeoDataFrame(FOOD_1)
FOOD_1.crs

# %%
FOOD_1.crs

# %%
fig, ax = plt.subplots(figsize=(15,10))
NYC.plot(color='white', edgecolor='black', ax=ax)
FOOD_1.plot(column='Subindustry', marker='o', markersize=25, legend=True, ax=ax)
plt.title('Times Square Food & Beverage Locations',  fontsize=20)

# %% [markdown]
# **Figure 2:** 'Times Square Food & Beverage Locations' data is provided by Times Square Alliance (TSA), which indicates each specific shop with subindustry and location. This figure mainly plot their geolocation with subindustry. The number of shop which provided full service seems to be the largest amount, and the shop provided quick service tend to be at the edge of the square.
